# %% [markdown]
# <a href="https://colab.research.google.com/github/nasare34/Research-Deep-Learning-Techniques-for-Sickle-Cell-Anemia-classification/blob/main/Untitled36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import os

# %%
import os
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.applications import ResNet50
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Define the dataset folder path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')
nm_path = os.path.join(dataset_path, 'Non-anemic')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import tensorflow as tf
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #RESNET

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define dataset path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')
nm_path = os.path.join(dataset_path, 'Non-anemic')

# Defined image size and batch size
img_height = 224
img_width = 224
batch_size = 10

# Loaded the training and validation datasets
train_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Used 'categorical' for one-hot encoded labels
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Specifying the correct class labels
)

val_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Used 'categorical' for one-hot encoded labels
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']
)

# Define
model = Sequential()

# Download ResNet50. Removed the `classes` argument since we define that later.
pretrained_model = ResNet50(include_top=False,
                            input_shape=(224, 224, 3),  # Input shape dimension
                            pooling='avg',  # AvgPool
                            weights='imagenet')

# Disable training on ResNet50 layers
for layer in pretrained_model.layers:
    layer.trainable = False

# Add ResNet50 as the feature extractor
model.add(pretrained_model)

# Flatten all data
model.add(Flatten())

# Fully connected layers with 512 neurons
model.add(Dense(512, activation='relu'))

# Output layer with 2 neurons (for anemic and Non-anemic)
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True)

# Train the model
history = model.fit(train_ds, validation_data=val_ds, epochs=20, callbacks=[early_stop])
# Out:
# Found 710 files belonging to 2 classes.
# Using 568 files for training.
# Found 710 files belonging to 2 classes.
# Using 142 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 2048)                │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │           1,026 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,637,826 (93.99 MB)
#  Trainable params: 1,050,114 (4.01 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 1/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - accuracy: 0.5254 - loss: 0.7621 - val_accuracy: 0.6972 - val_loss: 0.6035
# Epoch 2/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - accuracy: 0.7094 - loss: 0.5608 - val_accuracy: 0.7606 - val_loss: 0.5482
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 158s 3s/step - accuracy: 0.7719 - loss: 0.4797 - val_accuracy: 0.7324 - val_loss: 0.5662
# Epoch 4/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.8256 - loss: 0.4564 - val_accuracy: 0.7465 - val_loss: 0.5587
# Epoch 5/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 144s 3s/step - accuracy: 0.8145 - loss: 0.4227 - val_accuracy: 0.7676 - val_loss: 0.4629
# Epoch 6/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 195s 2s/step - accuracy: 0.8906 - loss: 0.3514 - val_accuracy: 0.7817 - val_loss: 0.4559
# Epoch 7/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.8856 - loss: 0.3220 - val_accuracy: 0.7676 - val_loss: 0.4695
# Epoch 8/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9017 - loss: 0.3224 - val_accuracy: 0.7113 - val_loss: 0.5970
# Epoch 9/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.8602 - loss: 0.3214 - val_accuracy: 0.8028 - val_loss: 0.4415
# Epoch 10/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.9350 - loss: 0.2530 - val_accuracy: 0.7958 - val_loss: 0.4390
# Epoch 11/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - accuracy: 0.9146 - loss: 0.2517 - val_accuracy: 0.7958 - val_loss: 0.4349
# Epoch 12/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9018 - loss: 0.2554 - val_accuracy: 0.7958 - val_loss: 0.4271
# Epoch 13/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - accuracy: 0.9500 - loss: 0.2074 - val_accuracy: 0.7746 - val_loss: 0.4663
# Epoch 14/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9540 - loss: 0.1930 - val_accuracy: 0.7887 - val_loss: 0.4270
# Epoch 15/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9728 - loss: 0.1801 - val_accuracy: 0.7746 - val_loss: 0.4918
# Epoch 16/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9602 - loss: 0.1816 - val_accuracy: 0.8028 - val_loss: 0.4455
# Epoch 17/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9443 - loss: 0.1778 - val_accuracy: 0.7535 - val_loss: 0.5411
# Epoch 18/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.9562 - loss: 0.1707 - val_accuracy: 0.8099 - val_loss: 0.4075
# Epoch 19/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9775 - loss: 0.1171 - val_accuracy: 0.8028 - val_loss: 0.4004
# Epoch 20/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9783 - loss: 0.1282 - val_accuracy: 0.8028 - val_loss: 0.4214

# %%
# Visualize training results
plt.figure(figsize=(12, 6))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# #VALIDATION

# %%
# Visualizing predictions on validation set
class_names = ['Anemic', 'Non-anemic']

plt.figure(figsize=(10, 20))
for images, labels in val_ds.take(1):
    # Get the number of images in the batch
    num_images = len(images)
    # Calculate rows and columns for the subplot grid
    # You might need to adjust these based on your batch size
    num_rows = int(np.ceil(np.sqrt(num_images)))
    num_cols = int(np.ceil(num_images / num_rows))

    for i in range(num_images):
        result = model(np.expand_dims(images[i], axis=0))  # Make prediction for each image
        # Use num_rows and num_cols to dynamically create subplots
        ax = plt.subplot(num_rows, num_cols, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class = class_names[np.argmax(result)]  # Get the predicted class
        true_class = class_names[np.argmax(labels[i])]  # Get the true class
        plt.title(f"{predicted_class} {round(np.max(result), 2)} | {true_class}")
        plt.axis("off")

# Evaluate the model on val set
test_loss, test_accuracy = model.evaluate(val_ds)  # Use validation data here as a test
print(f"validation Loss: {test_loss:.4f} - validation Accuracy: {test_accuracy:.4f}")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.7970 - loss: 0.4338
# validation Loss: 0.4004 - validation Accuracy: 0.8028

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns



# Step 1: Make predictions on the validation set and extract labels
val_labels = []  # Initialize an empty list to store true labels
val_predictions = []  # Initialize an empty list to store predictions

for images, labels in val_ds:
    val_labels.extend(np.argmax(labels.numpy(), axis=1))  # Append true labels
    predictions = model.predict(images)
    val_predictions.extend(np.argmax(predictions, axis=1))  # Append predicted labels

# Convert the lists to NumPy arrays
val_labels = np.array(val_labels)
val_predictions = np.array(val_predictions)

# Step 2: Compute the confusion matrix and classification report
cm = confusion_matrix(val_labels, val_predictions)
class_report = classification_report(val_labels, val_predictions)

print("Classification Report:")
print(class_report)

# Step 3: Visualize the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(val_labels), yticklabels=np.unique(val_labels))
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        90
#            1       0.74      0.71      0.73        52
#
#     accuracy                           0.80       142
#    macro avg       0.79      0.78      0.79       142
# weighted avg       0.80      0.80      0.80       142

# %% [markdown]
# #TESTING

# %%
import os
import cv2
import numpy as np

# Defined the dataset path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')
nm_path = os.path.join(dataset_path, 'Non-anemic')

# Defined the function to load and preprocess images
def load_and_preprocess_images(folder_path, subfolders):
    label_map = {subfolder: idx for idx, subfolder in enumerate(subfolders)}
    images, labels = [], []

    for subfolder in subfolders:
        subfolder_path = os.path.join(folder_path, subfolder)
        for filename in os.listdir(subfolder_path):
            img_path = os.path.join(subfolder_path, filename)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, (224, 224))  # Resize to 224x224
                images.append(img)
                labels.append(label_map[subfolder])

    images = np.array(images).astype('float32') / 255.0  # Normalize images
    labels = np.array(labels)
    return images, labels

# Combine anemic and Non-amenic images into one test set
subfolders = ['Anemic', 'Non-anemic']  # Subfolders:
test_images, test_labels = load_and_preprocess_images(dataset_path, subfolders)

print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# Test images shape: (710, 224, 224, 3)
# Test labels shape: (710,)

# %%
test_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Ensure one-hot encoding
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Same class names as training
)

# Evaluate the model on the test set
resnet_loss, resnet_accuracy = model.evaluate(test_ds, verbose=1)
print(f"ResNet50 Model Test Loss: {resnet_loss:.4f} - ResNet50 Test Accuracy: {resnet_accuracy:.4f}")
# Out:
# Found 710 files belonging to 2 classes.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9650 - loss: 0.1598
# ResNet Model Test Loss: 0.1689 - Test Accuracy: 0.9535

# %%
# Step 1: Loaded the complete dataset (training + validation as a single dataset)
complete_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Use 'categorical' for one-hot encoded labels
    validation_split=None,     # Load the full dataset
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']   # Specify the correct class labels
)

# Step 2: Make predictions on the complete dataset and extract labels
complete_labels = []  # Initialize an empty list to store true labels
complete_predictions = []  # Initialize an empty list to store predictions

for images, labels in complete_ds:
    complete_labels.extend(np.argmax(labels.numpy(), axis=1))  # Append true labels
    predictions = model.predict(images)
    complete_predictions.extend(np.argmax(predictions, axis=1))  # Append predicted labels

# Convert the lists to NumPy arrays
complete_labels = np.array(complete_labels)
complete_predictions = np.array(complete_predictions)

# Step 3: Compute the confusion matrix and classification report
cm = confusion_matrix(complete_labels, complete_predictions)
class_report = classification_report(complete_labels, complete_predictions, target_names=['Anemic', 'Non-anemic'])

print("Classification Report:")
print(class_report)

# Step 4: Visualize the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Anemic', 'Non-anemic'], yticklabels=['Anemic', 'Non-anemic'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 710 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       Anemic       0.96      0.96      0.96       424
#   Non-anemic       0.94      0.94      0.94       286
#
#     accuracy                           0.95       710
#    macro avg       0.95      0.95      0.95       710
# weighted avg       0.95      0.95      0.95       710

# %% [markdown]
# #ROC CURVE

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Step 1: Get true labels and predicted probabilities for the complete dataset
complete_labels = []  # True labels
complete_probs = []   # Predicted probabilities

for images, labels in complete_ds:
    complete_labels.extend(np.argmax(labels.numpy(), axis=1))  # True labels (convert from one-hot)
    predictions = model.predict(images)  # Get predicted probabilities
    complete_probs.extend(predictions[:, 1])  # Probabilities for class '1' (Non-amemic)

# Convert to NumPy arrays
complete_labels = np.array(complete_labels)
complete_probs = np.array(complete_probs)

# Step 2: Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(complete_labels, complete_probs)
roc_auc = auc(fpr, tpr)

# Step 3: Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=1)  # Diagonal line for random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# #MULTI

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import os

# %%
import os
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.applications import ResNet50
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# %%
# !pip install classification_models
# Out:
# Collecting classification_models
#   Downloading classification_models-0.1.tar.gz (3.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: classification_models
#   Building wheel for classification_models (setup.py) ... done
#   Created wheel for classification_models: filename=classification_models-0.1-py3-none-any.whl size=4721 sha256=800ea89aa39285dfb0333d7fb8f47bc589608d1583d1927da1d3622241c11139
#   Stored in directory: /root/.cache/pip/wheels/93/f5/aa/94571fdff736593aefe73d07193ddbc5e1fdf71aed4d91693f
# Successfully built classification_models
# Installing collected packages: classification_models
# Successfully installed classification_models-0.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Define the dataset folder path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')
nm_path = os.path.join(dataset_path, 'Non-anemic')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import tensorflow as tf
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetV2B0, MobileNetV3Small
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define dataset path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')  # Anemic images
nm_path = os.path.join(dataset_path, 'Non-anemic')  # Non-anemic images

# Defined image size and batch size
img_height = 224
img_width = 224
batch_size = 10

# Loaded the training and validation datasets
train_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Used 'categorical' for one-hot encoded labels
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Specifying the correct class labels
)

val_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Used 'categorical' for one-hot encoded labels
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Specification the correct class labels
)

# Define input shape
input_shape = (img_height, img_width, 3)
input_layer = Input(shape=input_shape)

# Load EfficientNetV2B0 (latest version of EfficientNet)
effnet = EfficientNetV2B0(include_top=False, input_shape=input_shape, pooling='avg', weights='imagenet')(input_layer)
effnet = Flatten()(effnet)

# Load MobileNetV3Small (latest version of MobileNet)
mobilenet = MobileNetV3Small(include_top=False, input_shape=input_shape, pooling='avg', weights='imagenet')(input_layer)
mobilenet = Flatten()(mobilenet)

# Concatenate the outputs of both models
combined = Concatenate()([effnet, mobilenet])

# Add fully connected layers
x = Dense(512, activation='relu')(combined)
x = Dense(256, activation='relu')(x)

# Output layer with 2 neurons (for Anemic and Non-anemic)
output_layer = Dense(2, activation='softmax')(x)

# Create the final model
model = Model(inputs=input_layer, outputs=output_layer)

# Disable training on pretrained layers
for layer in model.layers:
    if "efficientnet" in layer.name.lower() or "mobilenet" in layer.name.lower():
        layer.trainable = False

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()

# Early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True)

# Train the model
history = model.fit(train_ds, validation_data=val_ds, epochs=20, callbacks=[early_stop])
# Out:
# Found 710 files belonging to 2 classes.
# Using 568 files for training.
# Found 710 files belonging to 2 classes.
# Using 142 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ efficientnetv2-b0         │ (None, 1280)           │      5,919,312 │ input_layer_2[0][0]    │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MobileNetV3Small          │ (None, 576)            │        939,120 │ input_layer_2[0][0]    │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_1 (Flatten)       │ (None, 1280)           │              0 │ efficientnetv2-b0[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_2 (Flatten)       │ (None, 576)            │              0 │ MobileNetV3Small[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 1856)           │              0 │ flatten_1[0][0],       │
# │                           │                        │                │ flatten_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 512)            │        950,784 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 256)            │        131,328 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 2)              │            514 │ dense_3[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,941,058 (30.29 MB)
#  Trainable params: 1,082,626 (4.13 MB)
#  Non-trainable params: 6,858,432 (26.16 MB)
# Epoch 1/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 77s 895ms/step - accuracy: 0.5808 - loss: 0.6759 - val_accuracy: 0.7183 - val_loss: 0.5912
# Epoch 2/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 75s 768ms/step - accuracy: 0.7432 - loss: 0.5577 - val_accuracy: 0.8099 - val_loss: 0.4976
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 48s 845ms/step - accuracy: 0.7968 - loss: 0.4813 - val_accuracy: 0.7746 - val_loss: 0.4880
# Epoch 4/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 49s 846ms/step - accuracy: 0.8075 - loss: 0.4605 - val_accuracy: 0.6831 - val_loss: 0.5604
# Epoch 5/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 79s 796ms/step - accuracy: 0.8335 - loss: 0.4192 - val_accuracy: 0.8028 - val_loss: 0.4184
# Epoch 6/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 46s 803ms/step - accuracy: 0.8507 - loss: 0.3480 - val_accuracy: 0.7746 - val_loss: 0.4446
# Epoch 7/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 82s 808ms/step - accuracy: 0.8484 - loss: 0.3445 - val_accuracy: 0.7887 - val_loss: 0.4394
# Epoch 8/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 84s 834ms/step - accuracy: 0.8901 - loss: 0.3040 - val_accuracy: 0.7465 - val_loss: 0.5200
# Epoch 9/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 47s 824ms/step - accuracy: 0.8911 - loss: 0.3042 - val_accuracy: 0.7958 - val_loss: 0.4336
# Epoch 10/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 80s 803ms/step - accuracy: 0.9244 - loss: 0.2480 - val_accuracy: 0.8028 - val_loss: 0.3874
# Epoch 11/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 45s 794ms/step - accuracy: 0.9121 - loss: 0.2347 - val_accuracy: 0.7958 - val_loss: 0.4234
# Epoch 12/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 45s 795ms/step - accuracy: 0.9129 - loss: 0.2327 - val_accuracy: 0.8310 - val_loss: 0.3895
# Epoch 13/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 83s 813ms/step - accuracy: 0.9445 - loss: 0.1848 - val_accuracy: 0.8310 - val_loss: 0.3702
# Epoch 14/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 46s 799ms/step - accuracy: 0.9756 - loss: 0.1559 - val_accuracy: 0.8099 - val_loss: 0.4180
# Epoch 15/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 84s 827ms/step - accuracy: 0.9489 - loss: 0.1505 - val_accuracy: 0.8028 - val_loss: 0.4228
# Epoch 16/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 47s 823ms/step - accuracy: 0.9678 - loss: 0.1365 - val_accuracy: 0.8592 - val_loss: 0.3955
# Epoch 17/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 46s 808ms/step - accuracy: 0.9715 - loss: 0.1265 - val_accuracy: 0.7887 - val_loss: 0.5371
# Epoch 18/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 83s 838ms/step - accuracy: 0.9387 - loss: 0.1571 - val_accuracy: 0.8451 - val_loss: 0.3908
# Epoch 19/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 80s 798ms/step - accuracy: 0.9835 - loss: 0.0813 - val_accuracy: 0.8310 - val_loss: 0.4114
# Epoch 20/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 45s 800ms/step - accuracy: 0.9803 - loss: 0.0849 - val_accuracy: 0.8592 - val_loss: 0.4136

# %%
# Visualize training results
plt.figure(figsize=(12, 6))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# #**VALIDATION**

# %%
# Visualizing predictions on validation set
class_names = ['Anemic', 'Non-anemic']

plt.figure(figsize=(10, 10))
for images, labels in val_ds.take(1):
    # Get the number of images in the batch
    num_images = len(images)
    # Calculate rows and columns for the subplot grid
    # You might need to adjust these based on your batch size
    num_rows = int(np.ceil(np.sqrt(num_images)))
    num_cols = int(np.ceil(num_images / num_rows))

    for i in range(num_images):
        result = model(np.expand_dims(images[i], axis=0))  # Make prediction for each image
        # Use num_rows and num_cols to dynamically create subplots
        ax = plt.subplot(num_rows, num_cols, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class = class_names[np.argmax(result)]  # Get the predicted class
        true_class = class_names[np.argmax(labels[i])]  # Get the true class
        plt.title(f"{predicted_class} {round(np.max(result), 2)} | {true_class}")
        plt.axis("off")

# Evaluate the model on val set
test_loss, test_accuracy = model.evaluate(val_ds)  # Use validation data here as a test
print(f"validation Loss: {test_loss:.4f} - validation Accuracy: {test_accuracy:.4f}")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 661ms/step - accuracy: 0.8146 - loss: 0.4528
# validation Loss: 0.3702 - validation Accuracy: 0.8310

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns



# Step 1: Make predictions on the validation set and extract labels
val_labels = []  # Initialize an empty list to store true labels
val_predictions = []  # Initialize an empty list to store predictions

for images, labels in val_ds:
    val_labels.extend(np.argmax(labels.numpy(), axis=1))  # Append true labels
    predictions = model.predict(images)
    val_predictions.extend(np.argmax(predictions, axis=1))  # Append predicted labels

# Convert the lists to NumPy arrays
val_labels = np.array(val_labels)
val_predictions = np.array(val_predictions)

# Step 2: Compute the confusion matrix and classification report
cm = confusion_matrix(val_labels, val_predictions)
class_report = classification_report(val_labels, val_predictions)

print("Classification Report:")
print(class_report)

# Step 3: Visualize the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(val_labels), yticklabels=np.unique(val_labels))
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 825ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 888ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 817ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        90
#            1       0.79      0.73      0.76        52
#
#     accuracy                           0.83       142
#    macro avg       0.82      0.81      0.81       142
# weighted avg       0.83      0.83      0.83       142

# %% [markdown]
# #**TESTING**

# %%
import os
import cv2
import numpy as np

# Defined the dataset path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')
nm_path = os.path.join(dataset_path, 'Non-anemic')

# Defined the function to load and preprocess images
def load_and_preprocess_images(folder_path, subfolders):
    label_map = {subfolder: idx for idx, subfolder in enumerate(subfolders)}
    images, labels = [], []

    for subfolder in subfolders:
        subfolder_path = os.path.join(folder_path, subfolder)
        for filename in os.listdir(subfolder_path):
            img_path = os.path.join(subfolder_path, filename)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, (224, 224))  # Resize to 224x224
                images.append(img)
                labels.append(label_map[subfolder])

    images = np.array(images).astype('float32') / 255.0  # Normalize images
    labels = np.array(labels)
    return images, labels

# Combine anemic and Non-amenic images into one test set
subfolders = ['Anemic', 'Non-anemic']  # Subfolders:
test_images, test_labels = load_and_preprocess_images(dataset_path, subfolders)

print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# Test images shape: (710, 224, 224, 3)
# Test labels shape: (710,)

# %%
test_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Ensure one-hot encoding
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Same class names as training
)

# Evaluate the model on the test set
resnet_loss, resnet_accuracy = model.evaluate(test_ds, verbose=1)
print(f" MobileNetV3SmallEfficientNetV2B0 Model Test Loss: {resnet_loss:.4f} -  MobileNetV3SmallEfficientNetV2B0 Test Accuracy: {resnet_accuracy:.4f}")
# Out:
# Found 710 files belonging to 2 classes.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 45s 622ms/step - accuracy: 0.9286 - loss: 0.2126
#  MobileNetV3SmallEfficientNetV2B0 Model Test Loss: 0.1710 -  MobileNetV3SmallEfficientNetV2B0 Test Accuracy: 0.9507

# %%
# Step 1: Loaded the complete dataset (training + validation as a single dataset)
complete_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Use 'categorical' for one-hot encoded labels
    validation_split=None,     # Load the full dataset
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']   # Specify the correct class labels
)

# Step 2: Make predictions on the complete dataset and extract labels
complete_labels = []  # Initialize an empty list to store true labels
complete_predictions = []  # Initialize an empty list to store predictions

for images, labels in complete_ds:
    complete_labels.extend(np.argmax(labels.numpy(), axis=1))  # Append true labels
    predictions = model.predict(images)
    complete_predictions.extend(np.argmax(predictions, axis=1))  # Append predicted labels

# Convert the lists to NumPy arrays
complete_labels = np.array(complete_labels)
complete_predictions = np.array(complete_predictions)

# Step 3: Compute the confusion matrix and classification report
cm = confusion_matrix(complete_labels, complete_predictions)
class_report = classification_report(complete_labels, complete_predictions, target_names=['Anemic', 'Non-anemic'])

print("Classification Report:")
print(class_report)

# Step 4: Visualize the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Anemic', 'Non-anemic'], yticklabels=['Anemic', 'Non-anemic'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 710 files belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 896ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 867ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 863ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 901ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 834ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 896ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 826ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 869ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       Anemic       0.96      0.96      0.96       424
#   Non-anemic       0.94      0.93      0.94       286
#
#     accuracy                           0.95       710
#    macro avg       0.95      0.95      0.95       710
# weighted avg       0.95      0.95      0.95       710

# %% [markdown]
# #ROC **CURVE**

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Step 1: Get true labels and predicted probabilities for the complete dataset
complete_labels = []  # True labels
complete_probs = []   # Predicted probabilities

for images, labels in complete_ds:
    complete_labels.extend(np.argmax(labels.numpy(), axis=1))  # True labels (convert from one-hot)
    predictions = model.predict(images)  # Get predicted probabilities
    complete_probs.extend(predictions[:, 1])

# Convert to NumPy arrays
complete_labels = np.array(complete_labels)
complete_probs = np.array(complete_probs)

# Step 2: Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(complete_labels, complete_probs)
roc_auc = auc(fpr, tpr)

# Step 3: Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=1)  # Diagonal line for random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 647ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 813ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 912ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 767ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 766ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 774ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 860ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 878ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 826ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 902ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 891ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step

# %% [markdown]
# #EfficientNetV2B0, MobileNetV3Small, **ResNet50V2**
#
#
# ---
#
#
#
# \

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Concatenate, Input, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetV2B0, MobileNetV3Small, ResNet50V2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.regularizers import l2

# Define dataset path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')  # anemic images
nm_path = os.path.join(dataset_path, 'Non-anemic')  # Non-anemic images

# Defined image size and batch size
img_height = 224
img_width = 224
batch_size = 35

# Loaded the training and validation datasets
train_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Used 'categorical' for one-hot encoded labels
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Specifying the correct class labels
)

val_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Used 'categorical' for one-hot encoded labels
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Specify the correct class labels
)

# Define input shape
input_shape = (img_height, img_width, 3)
input_layer = Input(shape=input_shape)

# Load EfficientNetV2B0
effnet = EfficientNetV2B0(include_top=False, input_shape=input_shape, pooling='avg', weights='imagenet')(input_layer)
effnet = Flatten()(effnet)

# Load MobileNetV3Small
mobilenet = MobileNetV3Small(include_top=False, input_shape=input_shape, pooling='avg', weights='imagenet')(input_layer)
mobilenet = Flatten()(mobilenet)

# Load ResNet50V2
resnet = ResNet50V2(include_top=False, input_shape=input_shape, pooling='avg', weights='imagenet')(input_layer)
resnet = Flatten()(resnet)

# Concatenate the outputs of all three models
combined = Concatenate()([effnet, mobilenet, resnet])

# Add fully connected layers with BatchNormalization and Dropout for regularization
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(combined)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)  # Dropout to prevent overfitting

x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)  # Dropout to prevent overfitting

x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)

# Output layer with 2 neurons (for Anemic and Non-anemic)
output_layer = Dense(2, activation='softmax')(x)

# Create the final model
model = Model(inputs=input_layer, outputs=output_layer)

# Disable training on pretrained layers
for layer in model.layers:
    if "efficientnet" in layer.name.lower() or "mobilenet" in layer.name.lower() or "resnet" in layer.name.lower():
        layer.trainable = False

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7)

# Train the model
history = model.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=[early_stop, reduce_lr])
# Out:
# Found 710 files belonging to 2 classes.
# Using 568 files for training.
# Found 710 files belonging to 2 classes.
# Using 142 files for validation.
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13            │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ efficientnetv2-b0         │ (None, 1280)           │      5,919,312 │ input_layer_13[0][0]   │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MobileNetV3Small          │ (None, 576)            │        939,120 │ input_layer_13[0][0]   │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resnet50v2 (Functional)   │ (None, 2048)           │     23,564,800 │ input_layer_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_9 (Flatten)       │ (None, 1280)           │              0 │ efficientnetv2-b0[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_10 (Flatten)      │ (None, 576)            │              0 │ MobileNetV3Small[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_11 (Flatten)      │ (None, 2048)           │              0 │ resnet50v2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 3904)           │              0 │ flatten_9[0][0],       │
# │ (Concatenate)             │                        │                │ flatten_10[0][0],      │
# │                           │                        │                │ flatten_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 1024)           │      3,998,720 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 1024)           │          4,096 │ dense_13[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 1024)           │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 512)            │        524,800 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 512)            │          2,048 │ dense_14[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 512)            │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 256)            │        131,328 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 256)            │          1,024 │ dense_15[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 2)              │            514 │ batch_normalization_8… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 35,085,762 (133.84 MB)
#  Trainable params: 4,658,946 (17.77 MB)
#  Non-trainable params: 30,426,816 (116.07 MB)
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 215s 11s/step - accuracy: 0.5676 - loss: 3.3628 - val_accuracy: 0.6338 - val_loss: 7.2758 - learning_rate: 0.0010
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 172s 9s/step - accuracy: 0.5671 - loss: 2.3819 - val_accuracy: 0.6338 - val_loss: 5.7657 - learning_rate: 0.0010
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 203s 9s/step - accuracy: 0.6366 - loss: 2.0206 - val_accuracy: 0.3803 - val_loss: 2.3815 - learning_rate: 0.0010
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 211s 10s/step - accuracy: 0.6543 - loss: 1.8998 - val_accuracy: 0.3873 - val_loss: 2.8983 - learning_rate: 0.0010
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 202s 10s/step - accuracy: 0.6315 - loss: 1.7780 - val_accuracy: 0.6408 - val_loss: 3.4791 - learning_rate: 0.0010
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 193s 9s/step - accuracy: 0.6207 - loss: 1.7286 - val_accuracy: 0.6549 - val_loss: 2.5210 - learning_rate: 0.0010
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 202s 9s/step - accuracy: 0.6891 - loss: 1.6737 - val_accuracy: 0.6549 - val_loss: 2.4883 - learning_rate: 0.0010
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 211s 10s/step - accuracy: 0.7100 - loss: 1.5881 - val_accuracy: 0.5845 - val_loss: 1.6136 - learning_rate: 0.0010
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 167s 10s/step - accuracy: 0.6473 - loss: 1.5974 - val_accuracy: 0.5775 - val_loss: 1.7097 - learning_rate: 0.0010
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 165s 10s/step - accuracy: 0.6667 - loss: 1.5670 - val_accuracy: 0.6549 - val_loss: 1.9012 - learning_rate: 0.0010
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 166s 10s/step - accuracy: 0.7345 - loss: 1.4673 - val_accuracy: 0.6268 - val_loss: 1.5552 - learning_rate: 0.0010
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 193s 9s/step - accuracy: 0.6697 - loss: 1.4676 - val_accuracy: 0.5634 - val_loss: 1.5661 - learning_rate: 0.0010
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 167s 10s/step - accuracy: 0.7052 - loss: 1.4354 - val_accuracy: 0.5282 - val_loss: 1.8633 - learning_rate: 0.0010
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 166s 10s/step - accuracy: 0.7048 - loss: 1.4138 - val_accuracy: 0.4014 - val_loss: 1.6619 - learning_rate: 0.0010
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 202s 10s/step - accuracy: 0.6991 - loss: 1.3812 - val_accuracy: 0.4648 - val_loss: 1.5926 - learning_rate: 0.0010
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 194s 9s/step - accuracy: 0.7358 - loss: 1.3368 - val_accuracy: 0.6338 - val_loss: 1.4349 - learning_rate: 0.0010
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 211s 10s/step - accuracy: 0.7204 - loss: 1.2988 - val_accuracy: 0.6620 - val_loss: 1.4534 - learning_rate: 0.0010
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 165s 10s/step - accuracy: 0.7193 - loss: 1.3034 - val_accuracy: 0.5775 - val_loss: 1.4271 - learning_rate: 0.0010
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 192s 9s/step - accuracy: 0.7111 - loss: 1.3122 - val_accuracy: 0.5282 - val_loss: 1.4925 - learning_rate: 0.0010
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 212s 10s/step - accuracy: 0.7222 - loss: 1.2999 - val_accuracy: 0.4859 - val_loss: 1.4538 - learning_rate: 0.0010
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 203s 10s/step - accuracy: 0.7198 - loss: 1.2855 - val_accuracy: 0.5141 - val_loss: 1.5009 - learning_rate: 0.0010
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 199s 10s/step - accuracy: 0.7470 - loss: 1.2191 - val_accuracy: 0.5845 - val_loss: 1.4426 - learning_rate: 0.0010
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 203s 10s/step - accuracy: 0.7435 - loss: 1.2221 - val_accuracy: 0.6338 - val_loss: 1.3572 - learning_rate: 0.0010
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 192s 9s/step - accuracy: 0.7638 - loss: 1.2067 - val_accuracy: 0.4366 - val_loss: 1.6032 - learning_rate: 0.0010
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 212s 10s/step - accuracy: 0.7399 - loss: 1.1838 - val_accuracy: 0.5070 - val_loss: 1.4283 - learning_rate: 0.0010
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 166s 10s/step - accuracy: 0.7512 - loss: 1.2058 - val_accuracy: 0.6268 - val_loss: 1.3132 - learning_rate: 0.0010
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 200s 10s/step - accuracy: 0.7573 - loss: 1.1590 - val_accuracy: 0.6761 - val_loss: 1.3420 - learning_rate: 0.0010
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 204s 10s/step - accuracy: 0.7422 - loss: 1.1821 - val_accuracy: 0.7324 - val_loss: 1.2539 - learning_rate: 0.0010
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 202s 10s/step - accuracy: 0.7295 - loss: 1.1560 - val_accuracy: 0.5070 - val_loss: 1.4296 - learning_rate: 0.0010
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 191s 9s/step - accuracy: 0.7661 - loss: 1.1166 - val_accuracy: 0.4859 - val_loss: 1.5026 - learning_rate: 0.0010
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 210s 10s/step - accuracy: 0.7690 - loss: 1.1117 - val_accuracy: 0.5000 - val_loss: 1.3793 - learning_rate: 0.0010
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 203s 10s/step - accuracy: 0.7463 - loss: 1.1212 - val_accuracy: 0.7606 - val_loss: 1.1839 - learning_rate: 0.0010
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 163s 10s/step - accuracy: 0.7540 - loss: 1.1050 - val_accuracy: 0.4577 - val_loss: 1.4969 - learning_rate: 0.0010
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 163s 10s/step - accuracy: 0.7227 - loss: 1.1530 - val_accuracy: 0.3662 - val_loss: 2.0541 - learning_rate: 0.0010
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 150s 9s/step - accuracy: 0.7574 - loss: 1.0661 - val_accuracy: 0.3732 - val_loss: 1.7771 - learning_rate: 0.0010
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 218s 10s/step - accuracy: 0.7925 - loss: 0.9987 - val_accuracy: 0.3732 - val_loss: 1.7331 - learning_rate: 0.0010
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 198s 10s/step - accuracy: 0.7666 - loss: 1.0244 - val_accuracy: 0.3592 - val_loss: 1.8719 - learning_rate: 0.0010
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 161s 10s/step - accuracy: 0.8010 - loss: 0.9807 - val_accuracy: 0.3732 - val_loss: 1.6811 - learning_rate: 2.0000e-04
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 161s 10s/step - accuracy: 0.7896 - loss: 0.9893 - val_accuracy: 0.3732 - val_loss: 1.7825 - learning_rate: 2.0000e-04
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 188s 9s/step - accuracy: 0.7822 - loss: 0.9610 - val_accuracy: 0.3662 - val_loss: 1.9223 - learning_rate: 2.0000e-04
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 214s 10s/step - accuracy: 0.7936 - loss: 0.9540 - val_accuracy: 0.3732 - val_loss: 1.6598 - learning_rate: 2.0000e-04
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 204s 10s/step - accuracy: 0.8236 - loss: 0.9397 - val_accuracy: 0.3944 - val_loss: 1.5866 - learning_rate: 2.0000e-04

# %%
# Visualize training results
plt.figure(figsize=(12, 6))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# #**validation**

# %%
# Visualizing predictions on validation set
class_names = ['Anemic', 'Non-anemic']

plt.figure(figsize=(10, 10))
for images, labels in val_ds.take(1):
    # Get the number of images in the batch
    num_images = len(images)
    # Calculate rows and columns for the subplot grid
    # You might need to adjust these based on your batch size
    num_rows = int(np.ceil(np.sqrt(num_images)))
    num_cols = int(np.ceil(num_images / num_rows))

    for i in range(num_images):
        result = model(np.expand_dims(images[i], axis=0))  # Make prediction for each image
        # Use num_rows and num_cols to dynamically create subplots
        ax = plt.subplot(num_rows, num_cols, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class = class_names[np.argmax(result)]  # Get the predicted class
        true_class = class_names[np.argmax(labels[i])]  # Get the true class
        plt.title(f"{predicted_class} {round(np.max(result), 2)} | {true_class}")
        plt.axis("off")

# Evaluate the model on val set
test_loss, test_accuracy = model.evaluate(val_ds)  # Use validation data here as a test
print(f"validation Loss: {test_loss:.4f} - validation Accuracy: {test_accuracy:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 6s/step - accuracy: 0.7547 - loss: 1.1823
# validation Loss: 1.1839 - validation Accuracy: 0.7606

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns



# Step 1: Make predictions on the validation set and extract labels
val_labels = []  # Initialize an empty list to store true labels
val_predictions = []  # Initialize an empty list to store predictions

for images, labels in val_ds:
    val_labels.extend(np.argmax(labels.numpy(), axis=1))  # Append true labels
    predictions = model.predict(images)
    val_predictions.extend(np.argmax(predictions, axis=1))  # Append predicted labels

# Convert the lists to NumPy arrays
val_labels = np.array(val_labels)
val_predictions = np.array(val_predictions)

# Step 2: Compute the confusion matrix and classification report
cm = confusion_matrix(val_labels, val_predictions)
class_report = classification_report(val_labels, val_predictions)

print("Classification Report:")
print(class_report)

# Step 3: Visualize the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(val_labels), yticklabels=np.unique(val_labels))
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 23s 8s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 813ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 519ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 920ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83        90
#            1       0.78      0.48      0.60        52
#
#     accuracy                           0.76       142
#    macro avg       0.77      0.70      0.71       142
# weighted avg       0.76      0.76      0.74       142

# %% [markdown]
# #TESTING

# %%
import os
import cv2
import numpy as np

# Defined the dataset path
dataset_path = '/content/drive/My Drive/Monkeypox'
mp_path = os.path.join(dataset_path, 'Anemic')
nm_path = os.path.join(dataset_path, 'Non-anemic')

# Defined the function to load and preprocess images
def load_and_preprocess_images(folder_path, subfolders):
    label_map = {subfolder: idx for idx, subfolder in enumerate(subfolders)}
    images, labels = [], []

    for subfolder in subfolders:
        subfolder_path = os.path.join(folder_path, subfolder)
        for filename in os.listdir(subfolder_path):
            img_path = os.path.join(subfolder_path, filename)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, (224, 224))  # Resize to 224x224
                images.append(img)
                labels.append(label_map[subfolder])

    images = np.array(images).astype('float32') / 255.0  # Normalize images
    labels = np.array(labels)
    return images, labels

# Combine anemic and Non-amenic images into one test set
subfolders = ['Anemic', 'Non-anemic']  # Subfolders:
test_images, test_labels = load_and_preprocess_images(dataset_path, subfolders)

print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# Test images shape: (710, 224, 224, 3)
# Test labels shape: (710,)

# %%
test_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Ensure one-hot encoding
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']  # Same class names as training
)

# Evaluate the model on the test set
resnet_loss, resnet_accuracy = model.evaluate(test_ds, verbose=1)
print(f" ResNet50V2MobileNetV3SmallEfficientNetV2B0 Model Test Loss: {resnet_loss:.4f} -  ResNet50V2MobileNetV3SmallEfficientNetV2B0 Test Accuracy: {resnet_accuracy:.4f}")
# Out:
# Found 710 files belonging to 2 classes.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 174s 8s/step - accuracy: 0.7366 - loss: 1.1902
#  ResNet50V2MobileNetV3SmallEfficientNetV2B0 Model Test Loss: 1.2083 -  ResNet50V2MobileNetV3SmallEfficientNetV2B0 Test Accuracy: 0.7268

# %%
# Step 1: Loaded the complete dataset (training + validation as a single dataset)
complete_ds = image_dataset_from_directory(
    dataset_path,
    label_mode='categorical',  # Use 'categorical' for one-hot encoded labels
    validation_split=None,     # Load the full dataset
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    class_names=['Anemic', 'Non-anemic']   # Specify the correct class labels
)

# Step 2: Make predictions on the complete dataset and extract labels
complete_labels = []  # Initialize an empty list to store true labels
complete_predictions = []  # Initialize an empty list to store predictions

for images, labels in complete_ds:
    complete_labels.extend(np.argmax(labels.numpy(), axis=1))  # Append true labels
    predictions = model.predict(images)
    complete_predictions.extend(np.argmax(predictions, axis=1))  # Append predicted labels

# Convert the lists to NumPy arrays
complete_labels = np.array(complete_labels)
complete_predictions = np.array(complete_predictions)

# Step 3: Compute the confusion matrix and classification report
cm = confusion_matrix(complete_labels, complete_predictions)
class_report = classification_report(complete_labels, complete_predictions, target_names=['Anemic', 'Non-anemic'])

print("Classification Report:")
print(class_report)

# Step 4: Visualize the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Anemic', 'Non-anemic'], yticklabels=['Anemic', 'Non-anemic'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 710 files belonging to 2 classes.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 529ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 533ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 973ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 518ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 539ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 519ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 541ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 537ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 528ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 510ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 831ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 515ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 538ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 527ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 538ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 528ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 961ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 514ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 519ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 510ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       Anemic       0.72      0.90      0.80       424
#   Non-anemic       0.76      0.47      0.58       286
#
#     accuracy                           0.73       710
#    macro avg       0.74      0.69      0.69       710
# weighted avg       0.73      0.73      0.71       710

# %% [markdown]
# #Roc Curve

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Step 1: Get true labels and predicted probabilities for the complete dataset
complete_labels = []  # True labels
complete_probs = []   # Predicted probabilities

for images, labels in complete_ds:
    complete_labels.extend(np.argmax(labels.numpy(), axis=1))  # True labels (convert from one-hot)
    predictions = model.predict(images)  # Get predicted probabilities
    complete_probs.extend(predictions[:, 1])

# Convert to NumPy arrays
complete_labels = np.array(complete_labels)
complete_probs = np.array(complete_probs)

# Step 2: Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(complete_labels, complete_probs)
roc_auc = auc(fpr, tpr)

# Step 3: Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=1)  # Diagonal line for random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 518ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 514ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 529ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 530ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 534ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 534ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 540ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 509ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 553ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 850ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 878ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 775ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 884ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 512ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 890ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 520ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 676ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 525ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 522ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
